# %% [markdown]
# # Bert Topic implementation

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)

# Load text data from output.txt
with open('output.txt', 'r') as f:
    text_data = [line.rstrip() for line in f.readlines()]

# %%
# %%capture
# !pip install bertopic

# %%
import bertopic
import pandas as pd

# Create a DataFrame with the documents
df = pd.DataFrame(text_data, columns=['documents'])

# Create a Bertopic model
model = bertopic.BERTopic()

# Fit the model to the documents
topics, _ = model.fit_transform(df['documents'])

# Visualize the topics
model.visualize_topics()
# Out:
# 2023-05-02 14:47:53.149992: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/anaconda/envs/Python3/lib:
# 2023-05-02 14:47:53.150038: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Get the top 5 topics for each document
df['topic'] = topics
df['top_5_topics'] = df['topic'].apply(lambda x: model.get_topic(x)[:5])
# Print the results
print(df)
# Out:
#                                               documents  topic  \
# 0           Sheffield waste site closed down by the ...     -1
# 1           Environment Agency completes third phase...     31
# 2           Environment Agency teams help flooded co...      4
# 3           Environment Agency prosecutes Lancashire...     -1
# 4           Repairs underway as Environment Agency b...      4
# ...                                                 ...    ...
# 6335        Afghanistan: US-Europe Group joint commu...     -1
# 6336        Farmers to have say on extending tax ave...      5
# 6337        Future maritime strategy - GOV.UK   Skip...     47
# 6338        Dounreay and Nuvia Ltd collaborate on be...     -1
# 6339  From:Dounreay Published5 December 2014The H5s ...     21
#
#                                            top_5_topics
# 0     [(and, 0.00730315879730006), (the, 0.007135619...
# 1     [(agency, 0.01147017197143046), (environment, ...
# 2     [(flood, 0.018656123847917424), (flooding, 0.0...
# 3     [(and, 0.00730315879730006), (the, 0.007135619...
# 4     [(flood, 0.018656123847917424), (flooding, 0.0...
# ...                                                 ...
# 6335  [(and, 0.00730315879730006), (the, 0.007135619...
# 6336  [(farmers, 0.02027144888874192), (farming, 0.0...
# 6337  [(maritime, 0.04275023622806945), (shipping, 0...
# 6338  [(and, 0.00730315879730006), (the, 0.007135619...
# 6339  [(flood, 0.02127727906956243), (flooding, 0.01...
#
# [6340 rows x 3 columns]

# %%
print("Number of topics:", len(model.get_topic_freq()))
# Out:
# Number of topics: 130

# %%
# %%capture 
pip isntall wordcoud
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import bertopic
import pandas as pd

np.random.seed(0)

# Load text data from output.txt
with open('output.txt', 'r') as f:
    text_data = [line.rstrip() for line in f.readlines()]

# Create a DataFrame with the documents
df = pd.DataFrame(text_data, columns=['documents'])

# Create a Bertopic model
model = bertopic.BERTopic()

# Fit the model to the documents
topics, _ = model.fit_transform(df['documents'])

# Get the top 5 topics for each document
df['topic'] = topics
df['top_5_topics'] = df['topic'].apply(lambda x: model.get_topic(x)[:5])

# %%
# Generate a word cloud for each of the first 20 topics
for i in range(20):
    print('topic{0}'.format(i))
    topic_words = [t[0] for t in model.get_topic(i)[:10]] # change 10 to however many words you want in the word cloud
    topic_freq_dict = dict(zip(topic_words, [1]*len(topic_words)))
    wordcloud = WordCloud(width=800, height=800, background_color='white').generate_from_frequencies(topic_freq_dict)
    plt.figure(figsize=(8,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad=0)
    plt.show()
# Out:
# topic0
# topic1
# topic2
# topic3
# topic4
# topic5
# topic6
# topic7
# topic8
# topic9
# topic10
# topic11
# topic12
# topic13
# topic14
# topic15
# topic16
# topic17
# topic18
# topic19

# %%
# Get a list of all topics sorted by frequency
topic_freq = model.get_topic_freq().value_counts().sort_values(ascending=False)
topic_list = topic_freq.index.to_list()
print(topic_list)
# Out:
# [(-1, 1896), (0, 399), (1, 258), (2, 253), (3, 134), (4, 106), (5, 102), (6, 88), (7, 85), (8, 81), (9, 77), (10, 76), (11, 70), (12, 68), (13, 66), (14, 66), (15, 64), (16, 64), (17, 55), (18, 54), (19, 52), (20, 47), (21, 43), (22, 41), (23, 38), (24, 36), (25, 35), (26, 34), (27, 33), (28, 33), (29, 32), (30, 32), (31, 32), (32, 32), (33, 32), (34, 32), (35, 31), (36, 31), (37, 30), (38, 30), (39, 29), (40, 29), (41, 29), (42, 28), (43, 27), (44, 26), (45, 26), (46, 26), (47, 25), (48, 25), (49, 25), (50, 25), (51, 25), (52, 24), (53, 24), (54, 24), (55, 24), (56, 24), (57, 23), (58, 23), (59, 23), (60, 22), (61, 22), (62, 21), (63, 21), (64, 21), (65, 21), (66, 21), (67, 20), (68, 20), (69, 20), (70, 20), (71, 20), (72, 20), (73, 20), (74, 19), (75, 19), (76, 19), (77, 18), (78, 18), (79, 18), (80, 17), (81, 17), (82, 17), (83, 17), (84, 17), (85, 16), (86, 16), (87, 16), (88, 16), (89, 15), (90, 15), (91, 15), (92, 15), (93, 14), (94, 14), (95, 14), (96, 14), (97, 13), (98, 13), (99, 13), (100, 13), (101, 13), (102, 13), (103, 13), (104, 13), (105, 13), (106, 13), (107, 13), (108, 13), (109, 13), (110, 13), (111, 13), (112, 12), (113, 12), (114, 12), (115, 12), (116, 11), (117, 11), (118, 11), (119, 11), (120, 11), (121, 11), (122, 11), (123, 11), (124, 11), (125, 11), (126, 10), (127, 10)]
