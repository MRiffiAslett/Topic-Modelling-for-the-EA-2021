# %%
@article{angelov2020top2vec,
      title={Top2Vec: Distributed Representations of Topics}, 
      author={Dimo Angelov},
      year={2020},
      eprint={2008.09470},
      archivePrefix={arXiv},
      primaryClass={cs.CL}
}
# Out:
#   File "/tmp/ipykernel_281/651286712.py", line 1
#     @article{angelov2020top2vec,
#             ^
# SyntaxError: invalid syntax

# %%
import PyPDF2
from top2vec import Top2Vec

# %%
# open the PDF file in read binary mode
with open('EA-2021.pdf', 'rb') as file:
    # create a PDF reader object
    pdf_reader = PyPDF2.PdfReader(file)

    # get the number of pages in the PDF file
    num_pages = len(pdf_reader.pages)

    # extract the text from each page of the PDF file
    pages_text = []
    for page_num in range(num_pages):
        page = pdf_reader.pages[page_num]
        page_text = page.extract_text()
        pages_text.append(page_text)

# %%
# create a Top2Vec model and fit it
model = Top2Vec(documents=documents)
# Out:
# 2023-04-28 15:17:57,954 - top2vec - INFO - Pre-processing documents for training
# INFO:top2vec:Pre-processing documents for training
# 2023-04-28 15:17:58,178 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2023-04-28 15:18:00,128 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# 2023-04-28 15:18:02,157 - top2vec - INFO - Finding dense areas of documents
# INFO:top2vec:Finding dense areas of documents
# 2023-04-28 15:18:02,164 - top2vec - INFO - Finding topics
# INFO:top2vec:Finding topics

# %%
topic_words, word_scores, topic_scores, topic_nums = model.search_topics(keywords=["air"], num_topics=model.get_num_topics())
for topic in topic_nums:
    model.generate_topic_wordcloud(topic)

# %% [markdown]
# #

# %%
from top2vec import Top2Vec

model_embeddingsv = Top2Vec(documents, embedding_model='universal-sentence-encoder')
# Out:
# 2023-04-28 15:06:33,642 - top2vec - INFO - Pre-processing documents for training
# /opt/anaconda/envs/Python3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 2023-04-28 15:06:33,899 - top2vec - INFO - Downloading universal-sentence-encoder model
# 2023-04-28 15:06:58.895005: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/anaconda/envs/Python3/lib:
# 2023-04-28 15:06:58.895037: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# ...
