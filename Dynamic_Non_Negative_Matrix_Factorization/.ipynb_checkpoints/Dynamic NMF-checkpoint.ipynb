# %% [markdown]
# # Non  Negative matrix Factorization

# %%
import os
import sys
import re

parent_directory = os.path.abspath('..')
sys.path.append(parent_directory)

from gensim.test.utils import common_texts
from gensim.corpora.dictionary import Dictionary
from Preprocess import preprocess
from Plot import plot_df
from gensim.models import Nmf


# Run the preprocessing 
df= preprocess('Data/articles.json')

# Create a dictionary from the tokenized documents
dictionary = Dictionary(df['content'])

common_corpus = [dictionary.doc2bow(text) for text in df['content']]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/faculty/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/faculty/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/faculty/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # Hyperparameter Tuning

# %%
import os
import sys
import re
from itertools import product
from gensim.models import Nmf
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from Preprocess import preprocess


# Define the parameter grid
param_grid = {
    'num_topics': [10, 20, 30, 40, 50],  # Number of topics
    'kappa': [0.01, 0.1, 0.5],  # Training step size
    'eval_every': [2, 5, 10]  # Evaluation interval
}

# Perform grid search
best_score = float('-inf')
best_model = None

for params in product(*param_grid.values()):
    kwargs = dict(zip(param_grid.keys(), params))
    nmf = Nmf(common_corpus, **kwargs)
    coherence_model = CoherenceModel(model=nmf, texts=df['content'], dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    if coherence_score > best_score:
        best_score = coherence_score
        best_model = nmf

print("Number of topics:", best_model.num_topics)
print("Kappa:", best_model.kappa)
print("Evaluation interval:", best_model.eval_every)
# Out:
# Number of topics: 7
# Kappa: 0.1
# Evaluation interval: 2

# %% [markdown]
# # Train model

# %%
import re
from gensim.models.nmf import Nmf

# Creating an instance of the NMF model
nmf = Nmf(common_corpus, num_topics=7, kappa=0.1, eval_every=2)

# Getting the topics using the get_topics() method
topics = nmf.print_topics(num_topics=40, num_words=10)

# Function to extract integer values
def extract_values(topic):
    # We're using a regex that matches digits inside the quotes
    values = re.findall(r'"(\d+)"', topic)
    return [dictionary[int(value)] for value in values]

# Applying the function to your data
result = [extract_values(topic[1]) for topic in topics]

# Print the result
for r in result:
    print(r)
# Out:
# ['flood', 'agenc', 'use', 'environ', 'help', 'set', 'govern', 'page', 'improv', 'new']
# ['use', 'govern', 'page', 'set', 'addit', 'search', 'help', 'improv', 'u', 'live']
# ['govern', 'help', 'flood', 'new', 'use', 'uk', 'support', 'work', 'improv', 'chang']
# ['flood', 'use', 'new', 'help', 'improv', 'environ', 'page', 'govern', 'set', 'addit']
# ['zone', 'premis', 'protect', 'near', 'surveil', 'km', 'follow', 'control', 'activ', 'aiv']
# ['use', 'page', 'set', 'addit', 'search', 'improv', 'help', 'govern', 'u', 'share']

# %% [markdown]
# # Coherence

# %%
from Plot import print_coherence
dic = dictionary
print_coherence(dic, result,df['content'])
# Out:
# Topic: govern,uk,use,new,set,page,help,addit,u,searc	Coherence: 0.46
# Topic: flood,agenc,use,environ,help,set,govern,page,	Coherence: 0.37
# Topic: use,govern,page,set,addit,search,help,improv,	Coherence: 0.65
# Topic: govern,help,flood,new,use,uk,support,work,imp	Coherence: 0.31
# Topic: flood,use,new,help,improv,environ,page,govern	Coherence: 0.42
# Topic: zone,premis,protect,near,surveil,km,follow,co	Coherence: 0.71
# Topic: use,page,set,addit,search,improv,help,govern,	Coherence: 0.60

# %% [markdown]
# # Dynamic NMF

# %%
df_copy = df.copy()
# Calculate the topic proportions for each document
topic_proportions = nmf.get_document_topics(common_corpus, minimum_probability=0, normalize=None)

# Add the topic proportions to the DataFrame
for i, topic in enumerate(result):
    topic_name = str(','.join(topic[:8]))
    df_copy[topic_name] = [doc_topic[i][1] for doc_topic in topic_proportions]

topic_means = df_copy.groupby('year-month').mean()

plot_df(topic_means)
# Out:
# /tmp/ipykernel_133/3290238005.py:10: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   topic_means = df_copy.groupby('year-month').mean()
