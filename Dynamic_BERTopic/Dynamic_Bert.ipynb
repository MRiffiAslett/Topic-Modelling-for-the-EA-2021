# %% [markdown]
# # Dynamic Bert

# %%
# %%capture
# !pip install bertopic

# %%
import sys
if 'google.colab' in sys.modules:
  from google.colab import drive
  drive.mount('/content/drive')
  # %cd /content/drive/MyDrive/yourrepository

# %%
import os
import sys
import re
import nltk
nltk.download('punkt')

parent_directory = os.path.abspath('..')
sys.path.append(parent_directory)

from gensim.test.utils import common_texts
from bertopic import BERTopic
from gensim.corpora.dictionary import Dictionary
from Preprocess import preprocess
from Plot import plot_df
df= preprocess('yourrepository/Data/articles.json')

# Create a dictionary from the tokenized documents
dictionary = Dictionary(df['content'])

common_corpus = [','.join(text).replace(',',' ') for text in df['content']]

# %% [markdown]
# # Hyperparameter Tuning

# %%
from bertopic import BERTopic
from sklearn.model_selection import GridSearchCV

# Define your data and other parameters
docs = [...]  # Your input documents
params = {
    'language': ['english', 'multilingual'],
    'top_n_words': [10, 20, 30],
    'n_gram_range': [(1, 1), (1, 2), (1, 3)],
    'min_topic_size': [10, 100, 500],
    'nr_topics': [None, 20, 50],
    'low_memory': [True, False]
}

# Initialize BERTopic model
model = BERTopic()

# Perform grid search for hyperparameter tuning
grid_search = GridSearchCV(model, param_grid=params, cv=5)
grid_search.fit(docs)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Print the best hyperparameters
print("Best Hyperparameters:")
for param, value in best_params.items():
    print(f"{param}: {value}")
# Out:
# Best Hyperparameters:
# language: english
# top_n_words: 20
# n_gram_range: (1, 2)
# min_topic_size: 100
# nr_topics: None
# low_memory: True

# %% [markdown]
# # Train model

# %%
language = "english"
top_n_words = 20
n_gram_range = (1, 2)
min_topic_size = 100
nr_topics = None
low_memory = True

# Initialize and train the BERTopic model
topic_model = BERTopic(language,top_n_words,n_gram_range,nr_topics,low_memory)

topics, probs = topic_model.fit_transform(common_corpus)

topic_model.save("my_model", serialization="safetensors")

BERTopic.load("my_model")

# %%
topic_model = BERTopic.load("my_model")

# %% [markdown]
# # Coherence Score

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

topic_words = topic_model.get_topics(10)['Main']
topics_proportions = [topic_words[i] for i in range(len(topic_words)-1)]

words_list = [[word[0] for word in sublist] for sublist in topics_proportions]
dictionary = Dictionary(df['content'])

from Plot import print_coherence
dic = dictionary
print_coherence(dic, words_list, df['content'])
# Out:
# Topic: flood,risk,scheme,coastal,agenc,defenc,warn,e	Coherence: 0.73
# Topic: use,govern,technolog,live,improv,open,support	Coherence: 0.41
# Topic: uk,trade,govern,research,space,support,intern	Coherence: 0.41
# Topic: water,compani,pollut,sewag,environ,treatment,	Coherence: 0.71
# Topic: fish,river,fisheri,licenc,angler,pa,agenc,sea	Coherence: 0.79
# Topic: appoint,chair,board,director,member,committe,	Coherence: 0.71
# Topic: wast,crime,illeg,carrier,oper,vehicl,agenc,po	Coherence: 0.72
# Topic: agenc,environ,wast,permit,site,illeg,use,crim	Coherence: 0.52
# Topic: need,want,speech,heritag,year,world,work,uk,p	Coherence: 0.39
# Topic: health,care,nh,patient,mental,research,social	Coherence: 0.79
# Topic: food,drink,export,farm,industri,product,gin,b	Coherence: 0.56
# Topic: fish,angler,licenc,fisheri,fine,illeg,rod,wit	Coherence: 0.88
# Topic: tree,woodland,plant,forestri,forest,commiss,n	Coherence: 0.74
# Topic: green,environment,natur,environ,govern,protec	Coherence: 0.46
# Topic: train,forc,arm,soldier,armi,defenc,militari,e	Coherence: 0.83
# Topic: river,lock,flood,agenc,boater,weir,thame,volu	Coherence: 0.63
# Topic: marin,ocean,protect,uk,cefa,area,blue,conserv	Coherence: 0.69
# Topic: cop,sharma,egypt,climat,alok,presid,syrian,as	Coherence: 0.54
# Topic: ivori,africa,uk,eleph,african,uganda,ban,trad	Coherence: 0.58
# Topic: farmer,farm,payment,land,slurri,scheme,agricu	Coherence: 0.74
# Topic: nuclear,reactor,decommiss,nda,sellafield,desi	Coherence: 0.63
# Topic: beach,coastal,bath,harbour,coast,flood,water,	Coherence: 0.62
# Topic: right,human,un,rapporteur,council,wto,intern,	Coherence: 0.78
# Topic: embassi,british,project,bid,support,propos,am	Coherence: 0.43
# Topic: ifca,fisheri,inshor,marin,fish,manag,angl,con	Coherence: 0.75
# Topic: medicin,amr,veterinari,resist,parcel,seizur,a	Coherence: 0.55
# Topic: ambassador,majesti,british,whittingham,embass	Coherence: 0.59
# Topic: permit,variat,consult,applic,ga,environment,o	Coherence: 0.69
# Topic: child,parent,abus,school,sexual,multiag,safeg	Coherence: 0.65
# Topic: air,qualiti,pollut,pilot,emiss,space,aircraft	Coherence: 0.43
# Topic: plastic,bag,charg,singleus,ban,straw,litter,c	Coherence: 0.94
# Topic: scotland,scottish,uk,mundel,glasgow,secretari	Coherence: 0.70
# Topic: chile,embassi,chilean,paraguay,british,santia	Coherence: 0.73
# Topic: boat,waterway,vessel,boater,registr,regist,un	Coherence: 0.86
# Topic: event,map,phase,speed,profil,recordhometransp	Coherence: 0.90
# Topic: prison,wast,jail,hmp,sentenc,probat,dump,offe	Coherence: 0.76
# Topic: coronaviru,covid,viru,test,food,infect,may,up	Coherence: 0.58
# Topic: salmon,stock,fish,river,byelaw,trout,catch,se	Coherence: 0.82
# Topic: biodivers,natur,speci,conserv,habitat,wildlif	Coherence: 0.81
# Topic: northumberland,tyne,flood,crayfish,river,coqu	Coherence: 0.55
# Topic: prime,minist,princ,down,prison,street,khan,ho	Coherence: 0.55
# Topic: farmer,farm,food,agricultur,product,eu,tenant	Coherence: 0.71
# Topic: road,vehicl,highway,cycl,car,park,autonom,tra	Coherence: 0.66
# Topic: un,peacekeep,polic,turkey,secur,presid,journa	Coherence: 0.68
# Topic: payment,bp,rural,rpa,farmer,claim,basic,schem	Coherence: 0.85
# Topic: fish,crayfish,angl,fisheri,licenc,agenc,river	Coherence: 0.73
# Topic: natur,england,appoint,board,chair,toni,junip,	Coherence: 0.67
# Topic: bath,water,qualiti,beach,standard,season,swim	Coherence: 0.76
# Topic: ealert,woodland,customersexplor,tree,walespub	Coherence: 0.96
# Topic: york,flood,fo,allevi,defenc,museum,garden,cit	Coherence: 0.72
# Topic: natur,england,coast,path,mene,landscap,peopl,	Coherence: 0.61
# Topic: space,safeti,spaceflight,satellit,solar,orbit	Coherence: 0.44
# Topic: rfcc,committe,coastal,flood,member,chair,appo	Coherence: 0.67
# Topic: drought,water,dri,rainfal,ndg,reservoir,group	Coherence: 0.78
# Topic: improv,busi,project,product,technolog,use,mot	Coherence: 0.33
# Topic: norfolk,agenc,barn,bird,poultri,banham,enviro	Coherence: 0.38
# Topic: peterborough,nottingham,nottinghamshir,hub,wa	Coherence: 0.50
# Topic: veterinari,medicin,antibiot,vmd,anim,pharmaco	Coherence: 0.71
# Topic: ocean,marin,sea,protect,blue,global,world,uk,	Coherence: 0.66
# Topic: guatemala,guatemalan,embassi,ambassador,cityp	Coherence: 0.83
# Topic: somerset,pollut,farm,fish,slurri,restock,agen	Coherence: 0.67
# Topic: robot,nuclear,research,fusion,innov,industri,	Coherence: 0.60
# Topic: school,pupil,build,psbp,rebuild,educ,teacher,	Coherence: 0.81
# Topic: governor,caico,turk,cabinet,tci,grand,excel,h	Coherence: 0.87
# Topic: essex,beaver,wast,path,natur,site,england,coa	Coherence: 0.38
# Topic: nh,format,trust,data,letter,assist,provid,soc	Coherence: 0.41
# Topic: woman,peac,gender,arm,health,equal,support,gi	Coherence: 0.63
# Topic: high,british,commission,sail,commiss,brunei,c	Coherence: 0.46
# Topic: london,tech,nigeria,maritim,trade,week,mayor,	Coherence: 0.45
# Topic: siren,warn,flood,test,grimsbi,cleethorp,hebde	Coherence: 0.72
# Topic: highway,cycl,england,road,cyclist,litter,desi	Coherence: 0.64
# Topic: paterson,owen,food,rural,gm,cent,per,product,	Coherence: 0.59
# Topic: coal,mine,author,water,solar,treatment,scheme	Coherence: 0.57
# Topic: train,pacer,submarin,carriag,airedal,passeng,	Coherence: 0.34
# Topic: foreign,secretari,commonwealth,uk,meet,fco,mi	Coherence: 0.69
# Topic: cumbria,river,cumbrian,restor,win,moss,trail,	Coherence: 0.47
# Topic: welsh,wale,secretari,gower,lamb,cairn,freepor	Coherence: 0.41
# Topic: pacif,partnership,partner,sellafield,climat,m	Coherence: 0.39
# Topic: bu,transport,freight,emiss,connect,vehicl,fun	Coherence: 0.61
# Topic: mp,parliamentari,state,secretari,hon,depart,m	Coherence: 0.77
# Topic: mexico,bid,format,assist,document,prosper,con	Coherence: 0.57
# Topic: esfa,educ,school,academi,skill,updat,fund,htm	Coherence: 0.71
# Topic: path,wast,middlesbrough,cambridgeshir,site,ho	Coherence: 0.29
# Topic: severn,trent,sewag,river,shad,discharg,water,	Coherence: 0.66
# Topic: macedonia,bih,kosovo,serbia,bosnia,herzegovin	Coherence: 0.56
# Topic: queen,royal,award,honour,madagascar,princess,	Coherence: 0.59
# Topic: oil,ga,tank,dropin,onshor,leak,regul,agenc,ho	Coherence: 0.43
# Topic: kenya,kenyan,seedbal,british,train,commission	Coherence: 0.57
# Topic: diseas,health,herpesviru,carp,khv,outbreak,sh	Coherence: 0.90
# Topic: russia,ukrain,russian,ukrainian,moldova,invas	Coherence: 0.80
# Topic: camera,huntingdon,worn,cambridg,nois,bodi,roa	Coherence: 0.22
# Topic: ireland,northern,radon,centenari,owl,ballykin	Coherence: 0.35
# Topic: stewardship,countrysid,tier,applic,farmer,woo	Coherence: 0.79
# Topic: fish,seafood,fisheri,uk,industri,fund,stock,m	Coherence: 0.60
# Topic: wast,fire,east,north,shee,site,court,sentenc,	Coherence: 0.66
# Topic: forest,leader,climat,lgbt,charter,global,disa	Coherence: 0.52
# Topic: afghanistan,taliban,uzbekistan,afghan,tajikis	Coherence: 0.51
# Topic: dorset,arn,moor,groundwat,wiltshir,flood,sila	Coherence: 0.36
# Topic: rail,network,cloud,hybrid,passeng,railway,fre	Coherence: 0.62
# Topic: divers,inclus,di,edi,equal,wargam,strategi,gs	Coherence: 0.43
# Topic: youth,young,peopl,singapor,climat,fund,millio	Coherence: 0.39
# Topic: insolv,tbt,compani,paint,ban,yealm,takeaway,s	Coherence: 0.38
# Topic: futur,climat,better,environment,world,technol	Coherence: 0.34
# Topic: cheven,scholarship,scholar,malaysia,studi,mas	Coherence: 0.73
# Topic: sheffield,cumbria,flood,smoke,radar,sheaf,riv	Coherence: 0.32

# %% [markdown]
# # Dynamic BERTopic

# %%
# %cd /content/drive/MyDrive/yourrepository/Dynamic_BERTopic
docs = df['content'].tolist()

# Your topic distribution matrix
topic_distr, _ = topic_model.approximate_distribution(common_corpus)

# Your topics dictionary
topics = topic_model.get_topics()

selected_topics = topics
# Appending topic distributions to dataframe
for topic_id, topic_keywords in selected_topics:
    topic_name = ' '.join([keyword for keyword, _ in topic_keywords])
    df[topic_name] = [distr[topic_id] for distr in topic_distr]

# %%
# %cd /content/drive/MyDrive/yourrepository
df_distribution= df

topic_means = df_distribution.groupby('year-month').mean()

plot_df(topic_means, 'BERTopic', add_error_bars = False)
